# %%
import yfinance as yf
import pandas as pd

# Télécharger le prix de l'or (Gold Futures)
gold = yf.download("GC=F", start="2005-01-01", interval="1d")

# Garde seulement Adj Close
gold = gold[["Close"]].rename(columns={"Close": "Gold"})

# Sauvegarder dans ton dossier raw
gold.to_csv("../data/raw/gold.csv" )
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_30408\161779622.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   gold = yf.download("GC=F", start="2005-01-01", interval="1d")
# [*********************100%***********************]  1 of 1 completed
